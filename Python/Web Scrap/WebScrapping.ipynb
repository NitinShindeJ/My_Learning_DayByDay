# %% [markdown]
# <a href="https://colab.research.google.com/github/NitinShindeJ/My_Learning_DayByDay/blob/master/Python/Web%20Scrap/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scrapping**

# %% [markdown]
# **Web Scrapping** is a technique employed to extract large amounts of data from websites whereby the data is extracted and saved to a local file in your computer or to a database in table format.

# %% [markdown]
# You’ll come across multiple libraries and frameworks in Python for web scraping. Here are three popular ones that do the task with efficiency and aplomb:
#
# * **BeautifulSoup**
# It is an amazing parsing library in Python that enables us to extract data from HTML and XML documents. It can automatically detect encodings and gracefully handles HTML documents even with special characters. We can navigate a parsed document and find what we need which makes it quick and painless to extract the data from the webpages. In this course, we will learn how to build web scrapers using Beautiful Soup in detail
#
# * **Scrapy**
# It is a framework for large scale web scraping. It gives you all the tools you need to efficiently **extract** data from websites, **process** them as you want, and store them in your preferred **structure** and format. You can read more about [scrapy](https://www.analyticsvidhya.com/blog/2017/07/web-scraping-in-python-using-scrapy/?utm_source=courses&amp;utm_medium=web-scraping-hands-on-introduction-pytho)
#
# * **Selenium**
# It is another popular tool for automating browsers. It’s primarily used for testing in the industry but is also very handy for web scraping. Check out this amazing [artical](https://www.analyticsvidhya.com/blog/2019/05/scraping-classifying-youtube-video-data-python-selenium/?utm_source=courses&utm_medium=web-scraping-hands-on-introduction-python) to know more about how it works in Python
#
# Here’s a brilliant illustration of the three main components that make up web scraping:
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/components-of-web-scraping.png)

# %% [markdown]
# # **Problem Statment**
#
# We’ll understand the components involved by scraping hotel details like the name of the hotel and price per room from the goibibo website:
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/target-url.png)
#
# Note: Always follow the [robots.txt](https://www.goibibo.com/robots.txt)  file of the target website which is also known as the robot exclusion protocol. This tells web robots which pages not to crawl.
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/updated_robots_goibibo.png)
#
# So, looks like we are allowed to scrape the data from our targeted URL. We are good to go and write the script of our web robot. Let’s begin!

# %% [markdown]
# The first step is to navigate to the target website and download the source code of the web page. We are going to use the [requests](https://pypi.org/project/requests/) library to do this. A couple of other libraries to make requests and download the source code are [http.client](https://docs.python.org/3/library/http.client.html#module-http.client) and [urlib2](https://docs.python.org/2/library/urllib2.html).

# %%
# Import Libraries 
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %%
# target URL to scrap
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

# headers
headers = {'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"}

# send request to download the data
response = requests.request("GET", url, headers=headers)
#response = requests.get(url)

# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true">Hotels in Shimla, 517 Shimla Hotels from ₹300 + upto 30% off</title>
# <meta content="#2d67b2" data-react-helmet="true" name="theme-color"/><meta content="122023101161980" data-react-helmet="true" property="fb:app_id"/><meta content="239522418693" data-react-helmet="true" property="fb:pages"/><meta content="l3rQIge7B2N_G1cQl0VZP0y7-nE" data-react-helmet="true" name="alexaVerifyID"/><meta charset="utf-8" data-react-helmet="true"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" data-react-helmet="true" name="viewport"/><meta content="Book Hotels in Shimla at lowest Prices on Goibibo. Get Free Cancellation and Instant Refund on 517  Shimla Hotels starting from  ₹300. Book from 96 goSafe Hotels in Shimla, ensuring clean and safe hotel stay in current Coronavirus scenario. Use code GETSETGO for discounts upto 30% off on Budget and Luxury Shimla Hotels." data-react-helmet="true" name="description"/><meta content="Book Hotels in Shimla at lowest Prices on Goibibo. Get Free Cancellation and Instant Refund on 517  Shimla Hotels starting from  ₹300. Book from 96 goSafe Hotels in Shimla, ensuring clean and safe hotel stay in current Coronavirus scenario. Use code GETSETGO for discounts upto 30% off on Budget and Luxury Shimla Hotels." data-react-helmet="true" property="og:description"/><meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" data-react-helmet="true" name="keywords"/><meta content="Hotels in Shimla, 517  Shimla Hotels from  ₹300 + upto 30% off" data-react-helmet="true" property="og:title"/><meta content="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" data-react-helmet="true" property="og:url"/><meta content="Fri Jul 31 2020 00:33:38 GMT+0530 (India Standard Time)" data-react-helmet="true" name="timestamp"/>
# <link data-react-helmet="true" href="/favicon.ico" rel="shortcut icon"/><link data-react-helmet="true" href="/manifest.json" rel="manifest"/><link data-react-helmet="true" href="//goibibo.ibcdn.com/" rel="preconnect"/><link data-react-helmet="true" href="//goibibo.ibcdn.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//hermes.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//voyager.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link data-react-helmet="true" href="//ugc.goibibo.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//www.googletagmanager.com" rel="dns-prefetch"/><link data-react-helmet="true" href="//www.google-analytics.com" rel="dns-prefetch"/><link data-react-helmet="true" href="https://goibibo.ibcdn.com/hotelsnew/static/images/go@2x.png" rel="icon" sizes="192x192"/><link data-react-helmet="true" href="/favicon.ico" rel="shortcut icon"/><link data-react-helmet="true" href="https://goibibo.ibcdn.com/styleguide/css/combinedStyles.css" media="all" rel="stylesheet" type="text/css"/><link data-react-helmet="true" href="http://www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><link data-react-helmet="true" href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" rel="canonical"/><link data-react-helmet="true" href="android-app://com.goibibo/goibibo/www.goibibo.com/app/hotels/hotels-in-shimla-ct/?params={'go_data': {'n': u'shimla', 'oid': '1449073512565742573', 't': 'area', 'cid': '1449073512565742573'}, 'tag_id': 202}" rel="alternate"/>
# <style data-styled="gyznxm gJWDur eWmLvU etaRAY jEqbKC IiDSL ewNiTR kxdfo dZatas iHWQPB jeaZoS cmQYYX jFqKYz hcRCsh gYYXNq kCPVCg jembVd juGEXM hvDXEU ZkxDP kJCdvj ekUpXp ksgKxx gTlbWF hQeJTA ewfAzo haAwXe eDIFxZ KUmcy enZqSv IQztv dwIKEJ jfTzob eFjeOX iccCJQ uqZaH dADaxr hfHSCx byWgZM hzVbAJ fUqAQu bKZTyM NgJdQ loWiYx eRKbhg imSlff iFqJNi hrXkEK kVomKj bokDHh cQODXM vJojJ kNaCCL jGKNlG klPanN jlTxqK gqeCFW ivFsDJ fwwxTW tUicE gjnDGK dzzzOb knSgUX caRqtb hOYfQZ dYjRpe cqPTuq ihYuJp dgKLZs fMiGWe dyrRfP jawPhZ SMyDr fsJRQJ kHSJXO edLiNJ jhlvJn jpKTmU jEUtnW jGBmhh ckdrFt impoLe fKLwTL AXpmD cZcfQa bRqjyH VIZhd iehlaw eaXvqx dnKZLR kOELuI lnvJsZ CouBH hzwgAF eXWmAQ fKNNeH hmlsFt dfSYRF bnEnYY iJpCKz fyzTkj dbYreR bcGOvP hivUQz gErUjJ iGkcms gMWZSi ksKWcf fyWKnD beqcaa daowQn gVnLtq hJwPoW fihdE jnRyOY dSCqXd ynTNd ljhRGN eBTmBT ebClZW iXOSqL kWDiZc iKCcrw pSdws fnpNI kSqQuN yKIfc eewuDU jUZxVU fRhGQt zxggi jgSvbc crLJti cGFGsN gPTIVA kfJfGR dSRAYa glvbyv jQDxLE eCHVqb cVKanx hfYeRA gzRVGf doVDVt exGXmF gLRazQ bZRGVV eNNZw gQZxND hxwKSt bfDcBr ewWMXe hTujpR kDurBh jDvTfP jZBlpi bidWQy iSPNpd kDzPFE jlZCtc gIAVzF kJvBeG eDjdLW VOVoq ftwHtX jYttnG bbRcbL iktjPq bHjUCi dIeYNu kyUyXa bsLGPo iHHsJV iFElQI gRkpfb kISnti cAFVCz hDSYCK jlNbef kbzcLQ eWvkLZ jIaaDs ibjxlo jeFLde dcYQoP hYJvru iaSiXq hzneEr kPCZmY kwDkJw jkwhbV hiSwbR dlEtqh beangL bsmZUs eYCzxX hDYpQA iAfyQd extGxz cnlGUa hZsSYG jyOpAo dZOyRu fmkJQI ccnDzg fbCOAB lkvAhT kKGfMS Cfkq jRvRGe kQzGvm ggPRek bFlMoa jeSzhI hcmBQZ eWWXeq hRWyaO gxraxF ebMGJs kejKIk jwQfds iuvdUD hqJiCj kwRIYo iBJJqj gkczzq gRDTkp eVvhTZ fIWNKa gHuhQg cYXNlx gcCNmJ frCuQN dWVSUG gLJOue grMCCx dMzNlX kjZXPq eEeBmU dfIkHO cmSHgk SOSTG kkgKGx jCPYBe kkyTiJ cirvHm hqhFhI kXdvIu lhfGdZ iNlCAn exNKgl iLNhYa hBrrKv kzHCgB jCmwWH ftBpkQ cAkSRz iQuwzE eybAbg ctgEEt WJVKN kqLsfP fuxNsO dZTbef cANAqM kybynB eldAWK fsqkso jpNozZ bfWSlp cwEbLP kfcAaB inZapl Igtul OLzAk fDuNiT jzkPor cimUfb iOqpdx jdDuUB jpXACn eKhfyA bnPLlm cJucJg fFVwhk fuALhf dQRrhW fZdjVi hdJGFG ctiXar jGAHvj kpucnG qyiCH jdTJiu QDXMv" data-styled-version="4.4.1">
# /* sc-component-id: sc-global-1502425927 */
# @import url('https://fonts.googleapis.com/css?family=Quicksand:400,700&display=swap'); html{font-size:10px;} html,.scroll-container{overflow-y:scroll;} html.modal-open{overflow:hidden;} body.moda-open{overflow:inherit;} @media (prefers-reduced-motion){html,.scroll-container{-webkit-scroll-behavior:auto;-moz-scroll-behavior:auto;-ms-scroll-behavior:auto;scroll-behavior:auto;}} *{padding:0;margin:0;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;} .headerBox{z-index:99;} .oh{height:110vh;overflow-y:hidden;position:fixed;width:100%;margin:0px auto;} body{background:#eef4fd;color:#141823;font:400 1.2rem/1.33 "Helvetica Neue",Helvetica,Arial,sans-serif;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}
# /* sc-component-id: DetailsPageLayoutstyles__WrapperSection-t8l2sc-0 */
# .eKhfyA{background-color:#eef4fd;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: DetailsPageLayoutstyles__WrapperDiv-t8l2sc-1 */
# .bnPLlm{max-width:120rem;width:100%;padding-top:1.5rem;margin:0 auto;}
# /* sc-component-id: ContentContainerstyles__MainContentWrapperStyle-jinyls-0 */
# .dQRrhW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:2.5rem;width:100%;}
# /* sc-component-id: ContentContainerstyles__ContentWrapper-jinyls-2 */
# .fZdjVi{font-size:1.6rem;line-height:1.4;overflow:hidden;height:undefinedpx;}
# /* sc-component-id: AboutPropertiesstyles__HeadingTextWrapperStyle-sc-4xqpe7-1 */
# .fFVwhk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;border-bottom:0.1rem solid #dcddde;padding:2rem 2.5rem;}
# /* sc-component-id: AboutPropertiesstyles__MainContentTextStyle-sc-4xqpe7-2 */
# .cJucJg{font-size:1.6rem;line-height:1.4;background:white;border-radius:1.2000000000000002rem;} .cJucJg >p{height:100%;}
# /* sc-component-id: AboutPropertiesstyles__HeadingTextStyle-sc-4xqpe7-3 */
# .fuALhf{font-size:2.2rem;font-family:Quicksand;font-weight:bold;}
# /* sc-component-id: dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 */
# .dgKLZs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: dwebCommonstyles__CenteredDivWrap-sc-112ty3f-1 */
# .hvDXEU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: dwebCommonstyles__BaseColumnWrap-sc-112ty3f-2 */
# .hcRCsh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}
# /* sc-component-id: dwebCommonstyles__FlexItem-sc-112ty3f-3 */
# .eWmLvU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: dwebCommonstyles__PrimaryLink-sc-112ty3f-7 */
# .jeSzhI{color:#2276e3;}
# /* sc-component-id: SearchWidgetUIstyles__OuterWrapDiv-sc-1pb2jm7-0 */
# .gyznxm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;position:-webkit-sticky;position:sticky;top:-.01rem;z-index:9;background-color:#2276e3;}
# /* sc-component-id: SearchWidgetUIstyles__WrapperStyle-sc-1pb2jm7-1 */
# .gJWDur{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;max-width:120rem;width:100%;margin:0 auto;padding:1.2000000000000002rem 0;background-color:#2276e3;}
# /* sc-component-id: SearchWidgetUIstyles__SearchWrapperArea-sc-1pb2jm7-2 */
# .etaRAY{width:33.7rem;padding-right:1.2000000000000002rem;position:relative;}
# /* sc-component-id: SearchWidgetUIstyles__CheckinCheckoutWrapper-sc-1pb2jm7-3 */
# .dZatas{padding-right:1.2000000000000002rem;}
# /* sc-component-id: SearchWidgetUIstyles__PaxWrapperStyle-sc-1pb2jm7-4 */
# .cmQYYX{padding-right:0.5rem;position:relative;}
# /* sc-component-id: SearchWidgetUIstyles__SearchLabelStyle-sc-1pb2jm7-5 */
# .iHWQPB{color:white;padding-bottom:0.5rem;padding-left:0.2rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6 */
# .jeaZoS{background-color:#1951b5;color:white;border:none;font-size:1.6rem;font-family:Quicksand;font-weight:bold;display:block;width:100%;height:4.2rem;padding:1rem 1rem 1.2000000000000002rem 1rem;line-height:1.3;border-radius:0.8rem;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-packjustify-conent:center;-webkit-justify-conent:center;-ms-flex-packjustify-conent:center;justify-conent:center;} .jeaZoS::-webkit-input-placeholder{color:white;opacity:0.5;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-size;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-family;.SearchWidgetUIstyles__SearchInputStyle-sc-1pb2jm7-6.font-weight;} .jeaZoS:focus{box-shadow:none;outline:none;}
# /* sc-component-id: SearchWidgetUIstyles__UpdateSearchBtn-sc-1pb2jm7-7 */
# .jFqKYz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;border:none;background-color:#ff6d38;color:#ffffff;font-family:Quicksand;font-weight:bold;text-transform:uppercase;border-radius:1.2000000000000002rem;font-size:1.6rem;background-color:#ffffff;margin-top:1.5rem;height:4.2rem;width:19.6rem;color:#141823;} .jFqKYz:focus{box-shadow:none;outline-offset:0;outline:0;}
# /* sc-component-id: SearchWidgetAutosuggeststyles__AutocompleteWrapperStyles-agkhrg-0 */
# .jEqbKC{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;}
# /* sc-component-id: SearchWidgetAutosuggeststyles__SearchInputStyles-agkhrg-1 */
# .ewNiTR{background-color:#1951b5;color:white;border:none;font-size:1.6rem;font-family:Quicksand;font-weight:bold;text-transform:capitalize;display:block;width:100%;height:4.2rem;padding:1rem 1rem 1.2000000000000002rem 1rem;line-height:1.3;border-radius:0.8rem;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-packjustify-conent:center;-webkit-justify-conent:center;-ms-flex-packjustify-conent:center;justify-conent:center;} .ewNiTR::-webkit-input-placeholder{color:white;opacity:0.5;.SearchWidgetAutosuggeststyles__SearchInputStyles-agkhrg-1.font-size;.SearchWidgetAutosuggeststyles__SearchInputStyles-agkhrg-1.font-family;.SearchWidgetAutosuggeststyles__SearchInputStyles-agkhrg-1.font-weight;} .ewNiTR:focus{box-shadow:none;outline:none;}
# /* sc-component-id: SearchWidgetAutosuggeststyles__SearchLabelStyles-agkhrg-2 */
# .IiDSL{color:#ffffff;padding-bottom:0.5rem;padding-left:0.2rem;}
# /* sc-component-id: HomePageAutosuggeststyles__SearchMenuStyles-sc-1v6s32j-3 */
# .kxdfo{z-index:99;position:absolute;top:6rem;left:0;list-style-type:none;background:#ffffff;border-radius:4px;box-shadow:0 2px 14px 0 rgba(0,0,0,0.16);-webkit-transform:translateY(4px);-ms-transform:translateY(4px);transform:translateY(4px);min-width:54rem;max-height:90vh;overflow-y:auto;} .kxdfo .HomePageAutosuggeststyles__SearchListItem-sc-1v6s32j-2 :first-of-type{border-top:none;}
# /* sc-component-id: HotelIcon-sc-3dg9f4-0 */
# .ZkxDP{width:2.2rem;height:2.2rem;fill:#2276e3;cursor:pointer;}
# /* sc-component-id: ArrowDownIcon-sc-1rvxdsg-0 */
# .jfTzob{width:1rem;height:1rem;fill:#2276e3;margin:0 0 0 0.5rem;cursor:pointer;}
# /* sc-component-id: CheckBoxUncheckedIcon-sc-13ilmpa-0 */
# .fsJRQJ{margin-right:1rem;width:1.6rem;height:1.6rem;cursor:pointer;}
# /* sc-component-id: RatingStarIcon-sc-1lv0lb2-0 */
# .ckdrFt{cursor:pointer;}
# /* sc-component-id: PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 */
# .dfSYRF{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:0.8rem;position:absolute;right:2rem;top:-1rem;} .dfSYRF:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-1{visibility:visible;}.bnEnYY{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:0.8rem;} .bnEnYY:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-1{visibility:visible;}.iJpCKz{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-right:0.8rem;margin-top:0.5rem;} .iJpCKz:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-1{visibility:visible;}.fyzTkj{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;} .fyzTkj:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-1{visibility:visible;}.dbYreR{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;margin-top:0.5rem;} .dbYreR:hover > .PersuasionHoverTextstyles__HiddenDropdownWrapperDiv-sc-1c06rw1-1{visibility:visible;}
# /* sc-component-id: PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 */
# .hmlsFt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: PersuasionHoverTextstyles__TextWrapperSpan-sc-1c06rw1-14 */
# .dlEtqh{border-radius:1.5rem;cursor:pointer;color:#2276e3;background-color:white;text-transform:capitalize;padding:0.3rem 0 0.3rem 0;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .dlEtqh span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.beangL{border-radius:1.5rem;cursor:pointer;color:#2276e3;background-color:#eef4fd;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .beangL span{max-width:16rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.bsmZUs{border-radius:1.5rem;cursor:pointer;color:#ff6d38;background-color:#ffffff;text-transform:capitalize;padding:0.3rem 0 0.3rem 0;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .bsmZUs span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.eYCzxX{border-radius:1.5rem;cursor:pointer;color:#2bac36;background-color:#e9f6ea;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .eYCzxX span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.hDYpQA{font-size:1.2rem;border-radius:0.2rem;cursor:pointer;color:#ffffff;background-color:linear-gradient(107deg,#1149f3,#00c3ff);background-image:linear-gradient(107deg,#1149f3,#00c3ff);text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .hDYpQA span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.iAfyQd{font-size:1.2rem;border-radius:0.2rem;cursor:pointer;color:#4f525a;background-color:#eef4fd;text-transform:capitalize;padding:0.3rem 0.8rem 0.3rem 0.8rem;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .iAfyQd span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.extGxz{border-radius:1.5rem;cursor:pointer;color:#4f525a;background-color:#ffffff;text-transform:capitalize;padding:0.3rem 0 0.3rem 0;border:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .extGxz span{max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}
# /* sc-component-id: PersuasionHoverTextstyles__MainTextIconWrapperSpan-sc-1c06rw1-18 */
# .jyOpAo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:0.8rem;}
# /* sc-component-id: RoundedCheckbox-sc-4skzta-0 */
# .kwRIYo{width:1.5rem;height:1.5rem;} .kwRIYo g path:last-child{fill:#898b91;}
# /* sc-component-id: CoupleFriendlyIcon-sc-1akp97f-0 */
# .gTlbWF{width:2.2rem;height:2.2rem;fill:#898b91;cursor:pointer;}.hQeJTA{width:1.6rem;height:1.6rem;fill:#ff6d38;cursor:pointer;}
# /* sc-component-id: GiftTagIcon-sc-1f8umx7-0 */
# .bfWSlp{height:3.2rem;fill:#2276e3;cursor:pointer;}
# /* sc-component-id: UgcPersuasionIcon-xk3nsn-0 */
# .dZOyRu{width:1.6rem;height:1.6rem;cursor:pointer;} .dZOyRu g path:last-child{fill:#2276e3;}.fmkJQI{width:1.6rem;height:1.6rem;cursor:pointer;} .fmkJQI g path:last-child{fill:#4f525a;}
# /* sc-component-id: SwimmingIcon-sc-2o20qz-0 */
# .jwQfds{width:1.2rem;height:1.2rem;fill:#2276e3;cursor:pointer;}
# /* sc-component-id: goSafeSheildLogo__GoSafeSheildLogo-ftpml2-0 */
# .kJCdvj{width:2.2rem;height:2.2rem;fill:#2276e3;cursor:pointer;}
# /* sc-component-id: TriggerActionText__TriggerAnchorText-sc-1vbd2op-0 */
# .jCPYBe{color:#2276e3;width:100%;height:100%;display:inline;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:auto;} .jCPYBe a:visited{color:#2276e3;}
# /* sc-component-id: GoSafeDetailedPersuasionstyles__GoSafeMainContainer-sc-7q397w-0 */
# .gHuhQg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;border-radius:0.6000000000000001rem;background-color:#E7F5EF;padding:0.5rem;border:0.1rem solid #9de0c0;}
# /* sc-component-id: GoSafeDetailedPersuasionstyles__TextContentNormalSpan-sc-7q397w-2 */
# .gcCNmJ{padding-left:0.5rem;color:#141823;}
# /* sc-component-id: GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 */
# .cYXNlx{width:5rem;height:1.5rem;object-fit:contain;}
# /* sc-component-id: GoSafeTagPersuasionstyles__GoSafeTagContainer-fge448-1 */
# .fIWNKa{position:relative;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;cursor:pointer;}
# /* sc-component-id: AmenitiesListstyles__HiddenDropdownWrapperDiv-sc-19dqtu1-0 */
# .hcmBQZ{width:20rem;top:1.5rem;right:-2rem;max-width:30rem;padding:1rem 0;z-index:5;visibility:hidden;-webkit-transition:opacity 0.8s;transition:opacity 0.8s;position:absolute;}
# /* sc-component-id: AmenitiesListstyles__HoverTargetWrapperDiv-sc-19dqtu1-1 */
# .bFlMoa{position:relative;text-align:left;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;} .bFlMoa:hover > .AmenitiesListstyles__HiddenDropdownWrapperDiv-sc-19dqtu1-0{visibility:visible;}
# /* sc-component-id: AmenitiesListstyles__TopDiv-sc-19dqtu1-2 */
# .eWWXeq{background-color:#ffffff;border-radius:0.4rem;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}
# /* sc-component-id: AmenitiesListstyles__TipPositioning-sc-19dqtu1-4 */
# .eVvhTZ{position:absolute;margin-left:-1rem;width:2.4rem;height:1.2rem;overflow:hidden;right:15%;top:-0.2rem;} .eVvhTZ::after{content:'';position:absolute;width:1.3rem;height:1.2rem;left:50%;background:#d1e5ff;} .eVvhTZ::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}
# /* sc-component-id: AmenitiesListstyles__ListDropDownWrapper-sc-19dqtu1-5 */
# .hRWyaO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;list-style-type:none;overflow:hidden;padding:0.5rem 0 0;background:#d1e5ff;} .hRWyaO > li{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;border-bottom:0.1rem solid #eff3f8;padding:1rem;position:relative;} .hRWyaO > li:last-child{border-bottom:none;}
# /* sc-component-id: AmenitiesListstyles__IconWrapperDiv-sc-19dqtu1-6 */
# .kKGfMS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 1rem 0 0;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.Cfkq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:1rem;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: AmenitiesListstyles__TextWrapper-sc-19dqtu1-7 */
# .kQzGvm{padding-left:0.8rem;color:#4f525a;line-height:1.3;}
# /* sc-component-id: AmenitiesListstyles__TextBlockDDHeading-sc-19dqtu1-8 */
# .gxraxF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.30000000000000004rem 1rem 0.30000000000000004rem 0.5rem;background-color:white;color:#2276e3;border-radius:2.5rem;}
# /* sc-component-id: AmenitiesListstyles__TextBlockDDHeadingSpan-sc-19dqtu1-9 */
# .ebMGJs{padding:0 0 0 0.5rem;}
# /* sc-component-id: AmenitiesListstyles__MiniIconWrapperSpan-sc-19dqtu1-10 */
# .kejKIk{margin-right:0.5rem;}
# /* sc-component-id: AmenitiesListstyles__AmenitiesHoverTitleSpan-sc-19dqtu1-11 */
# .iuvdUD{margin-bottom:1rem;}
# /* sc-component-id: RupeeIcon-sc-5hlwf0-0 */
# .kjZXPq{width:1.5rem;height:1.5rem;fill:black;cursor:pointer;}.eEeBmU{width:1rem;height:1rem;fill:black;cursor:pointer;}
# /* sc-component-id: ActivitiesIcon-ffc2ds-0 */
# .ftBpkQ{width:2rem;height:2rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: AirportTransportIcon-bnhbgr-0 */
# .jzkPor{width:1.5rem;height:1,5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: BanquetHallIcon-sc-5ff6c4-0 */
# .jCmwWH{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: CctvIcon-pvucvd-0 */
# .kzHCgB{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: CleanRoomIcon-x0mze-0 */
# .iOqpdx{width:2rem;height:2rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: ConferenceRoomIcon-n8vzmu-0 */
# .jRvRGe{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: DailyHousekeepingIcon__DailyHouseKeepingIcon-sc-1af6fce-0 */
# .ggPRek{width:2rem;height:2rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: HouseKeepingIcon-sc-5ioupd-0 */
# .iBJJqj{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: ParkingIcon-sc-8rt39-0 */
# .cAkSRz{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: PowerBackupIcon-qb1oy8-0 */
# .gkczzq{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: RestaurantIcon-sc-1f8rkpo-0 */
# .gRDTkp{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: RoomServiceIcon-cq049u-0 */
# .OLzAk{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: SpaIcon-sc-1pedayu-0 */
# .fDuNiT{width:2rem;height:2rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: WifiIcon-sc-16t12vo-0 */
# .hqJiCj{width:1.5rem;height:1.5rem;fill:#898b91;cursor:pointer;}
# /* sc-component-id: BedIcon-pl6h8j-0 */
# .fbCOAB{cursor:pointer;} .fbCOAB width:function(e){return:e.width;} .fbCOAB height:function(e){return:e.height;} .fbCOAB fill:function(e){return:e.color;} .fbCOAB margin:function(e){return:e.margin;}
# /* sc-component-id: HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 */
# .eXWmAQ{cursor:pointer;}
# /* sc-component-id: HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 */
# .iGkcms{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:29%;padding:1.2000000000000002rem;position:relative;}
# /* sc-component-id: HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 */
# .fKNNeH{margin-bottom:1rem;background-color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-height:29rem;position:relative;border:.2rem solid transparent;border-radius:1.2000000000000002rem;} .fKNNeH:hover{border:0.2rem solid #2276e3;box-shadow:0 0.2rem 1.1rem 0 rgba(0,0,0,0.25);cursor:pointer;}
# /* sc-component-id: HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 */
# .jnRyOY{width:71%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 */
# .dSCqXd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:65%;padding:1.2000000000000002rem 1.2000000000000002rem 1.2000000000000002rem 0;}
# /* sc-component-id: HotelCardstyles__PersuasionWrapperDiv-sc-1s80tyk-8 */
# .cnlGUa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}
# /* sc-component-id: HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 */
# .ynTNd{width:100%;}
# /* sc-component-id: HotelCardstyles__HotelTypeTag-sc-1s80tyk-10 */
# .ljhRGN{color:#4f525a;padding:0.2rem;border:0.1rem solid #eff3f8;text-transform:uppercase;border-radius:0.2rem;margin:0 0.5rem;}
# /* sc-component-id: HotelCardstyles__HotelNameWrapperDiv-sc-1s80tyk-11 */
# .jkwhbV{width:30rem;padding:0.5rem 0;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;overflow:hidden;}
# /* sc-component-id: HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 */
# .hiSwbR{font-size:1.8rem;font-family:Quicksand;font-weight:bold;line-height:1.3;cursor:pointer;color:#141823;}
# /* sc-component-id: HotelCardstyles__RoomTypeWrapperDiv-sc-1s80tyk-13 */
# .hZsSYG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0.6rem 0 0.6rem 0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: HotelCardstyles__RoomTypeTextWrapper-sc-1s80tyk-14 */
# .lkvAhT{color:#4f525a;line-height:1.3;max-width:30rem;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}
# /* sc-component-id: HotelCardstyles__RoomTypeIconWrapperSpan-sc-1s80tyk-15 */
# .ccnDzg{margin-right:0.8rem;}
# /* sc-component-id: HotelCardstyles__HotelPricingInfoWrapperDiv-sc-1s80tyk-16 */
# .frCuQN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:35%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;border-radius:0 0.6000000000000001rem 0.6000000000000001rem 0;border-left:0.1rem solid #eef4fd;position:relative;}
# /* sc-component-id: HotelCardstyles__ContentWrapperDiv-sc-1s80tyk-17 */
# .dWVSUG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;padding:1rem 1.5rem;}
# /* sc-component-id: HotelCardstyles__PriceInfoWrapperDiv-sc-1s80tyk-22 */
# .gLJOue{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;margin:1rem 0;padding:0 1.5rem;}
# /* sc-component-id: HotelCardstyles__OriginalPriceTextWrapper-sc-1s80tyk-23 */
# .grMCCx{-webkit-text-decoration:line-through;text-decoration:line-through;color:#898b91;}
# /* sc-component-id: HotelCardstyles__CurrentPriceTextWrapper-sc-1s80tyk-24 */
# .dMzNlX{font-size:2.2rem;font-weight:bold;padding:0.2rem 0 0;}
# /* sc-component-id: HotelCardstyles__CurrentPrice-sc-1s80tyk-25 */
# .dfIkHO{font-family:Quicksand;}
# /* sc-component-id: HotelCardstyles__TaxPriceTextWrapper-sc-1s80tyk-26 */
# .cmSHgk{font-size:1rem;padding:0.2rem 0 0;text-transform:uppercase;}
# /* sc-component-id: HotelCardstyles__PerRoomNightTextWrapper-sc-1s80tyk-27 */
# .SOSTG{padding:0.2rem 0 0;color:#898b91;}
# /* sc-component-id: HotelCardstyles__SignUpTextWrap-sc-1s80tyk-29 */
# .lhfGdZ{cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:1.1rem;color:rgba(133,71,0,0.97);font-weight:bold;margin:0 0.5rem;}
# /* sc-component-id: HotelCardstyles__SignUpPriceWrap-sc-1s80tyk-30 */
# .iNlCAn{cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-weight:bold;font-size:1.4000000000000001rem;color:#4f525a;}
# /* sc-component-id: HotelCardstyles__SignUpPerNight-sc-1s80tyk-31 */
# .exNKgl{cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;color:#4f525a;}
# /* sc-component-id: HotelCardstyles__EMITextWrapperDiv-sc-1s80tyk-32 */
# .kkyTiJ{margin-bottom:0.5rem;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#141823;border:.1rem solid #eff3f8;padding:0.2rem;border-radius:0.4rem;}
# /* sc-component-id: HotelCardstyles__EMIContainer-sc-1s80tyk-33 */
# .kkgKGx{margin:1rem 0 0 0;}
# /* sc-component-id: HotelCardstyles__EMIWrap-sc-1s80tyk-34 */
# .cirvHm{border-radius:0.4rem;background-image:linear-gradient(105deg,#34393a,#adaeb2 100%);color:#ffffff;font-weight:bold;font-family:Quicksand;padding:0 0.29rem;margin-right:0.30000000000000004rem;}
# /* sc-component-id: HotelCardstyles__EMITextPrice-sc-1s80tyk-35 */
# .hqhFhI{color:#4f525a;font-weight:bold;margin-left:0.30000000000000004rem;}
# /* sc-component-id: HotelCardstyles__SignUpLockOuterWrapper-sc-1s80tyk-36 */
# .kXdvIu{display :-webkit-box;display :-webkit-flex;display :-ms-flexbox;display :flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:1rem;background:#fef8e5;padding:1rem;width:100%;border-bottom-right-radius:1.2000000000000002rem;border-top:.2rem solid #d1e5ff;padding:1rem 1.5rem 1rem 1rem;position:relative;}
# /* sc-component-id: HotelCardstyles__LockBackground-sc-1s80tyk-38 */
# .iLNhYa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:absolute;background:#fef8e5;width:100%;height:100%;opacity:0.47;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-animation:dQJvKY 1.5s 1s;animation:dQJvKY 1.5s 1s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;}
# /* sc-component-id: HotelCardstyles__SignUpLockWrapAnimated-sc-1s80tyk-39 */
# .hBrrKv{-webkit-animation-iteration-count:1;animation-iteration-count:1;-webkit-animation:tqjZn 1s 0.3s,fSYan 0.5s 1.3s;animation:tqjZn 1s 0.3s,fSYan 0.5s 1.3s;-webkit-transform-origin:bottom;-ms-transform-origin:bottom;transform-origin:bottom;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation-timing-function:ease-out;animation-timing-function:ease-out;opacity:1;position:absolute;top:29%;right:30%;} @media (min-width:768px) and (max-width:1024px){.hBrrKv{right:24%;}}
# /* sc-component-id: HotelCardstyles__SignUpLockWrap-sc-1s80tyk-40 */
# .jdDuUB{-webkit-transform-origin:bottom;-ms-transform-origin:bottom;transform-origin:bottom;opacity:1;position:absolute;top:29%;right:30%;-webkit-transform:translatex(-10rem) translatey(12rem) scale(0.3);-ms-transform:translatex(-10rem) translatey(12rem) scale(0.3);transform:translatex(-10rem) translatey(12rem) scale(0.3);}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SegmentSliderLoader-eae1g9-0 */
# .eybAbg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;border:0.1rem solid #eff3f8;padding:1rem;margin:1rem;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:32rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__BannerSliderLoader-eae1g9-1 */
# .ctgEEt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;height:11.5rem;margin-bottom :1rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderContentOuterWrap-eae1g9-2 */
# .WJVKN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderRatingLoader-eae1g9-4 */
# .fuxNsO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;width:7rem;height:1.5rem;margin-bottom :0.5rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderAddressLoader-eae1g9-5 */
# .dZTbef{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;width:15rem;height:5rem;margin-bottom :0.5rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderreviewsLoader-eae1g9-6 */
# .cANAqM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;width:7rem;height:1.5rem;margin-bottom :0.5rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderPriceLoader-eae1g9-7 */
# .kybynB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;width:10rem;height:7rem;margin-bottom :0.5rem;}
# /* sc-component-id: SegmentSliderHotelCardLoaderstyles__SliderOfferLoader-eae1g9-8 */
# .eldAWK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;background-color:#d1e5ff;border-radius:0.2rem;width:7rem;height:1.5rem;margin-bottom :0.5rem;}
# /* sc-component-id: GoStaysIcon-sc-6ymekq-0 */
# .ekUpXp{width:2.2rem;height:2.2rem;fill:#898b91;cursor:pointer;}.ksgKxx{width:3.2rem;height:3.2rem;fill:#ff6d38;cursor:pointer;}
# /* sc-component-id: ReviewAndRatingsstyles__GuestReviewPopUpWrap-sc-1nxmeoo-0 */
# .kSqQuN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;visibility:hidden;width:28rem;position:absolute;top:2.8rem;opacity:1;right:-15rem;padding:1rem;z-index:5;background-color:#ffffff;border-radius:0.4rem;box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}
# /* sc-component-id: ReviewAndRatingsstyles__HotelTotalReviewWrapper-sc-1nxmeoo-1 */
# .ebClZW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .ebClZW:hover > .ReviewAndRatingsstyles__GuestReviewPopUpWrap-sc-1nxmeoo-0{visibility:visible;}
# /* sc-component-id: ReviewAndRatingsstyles__ReviewAndRatingOuterContainer-sc-1nxmeoo-2 */
# .eBTmBT{position:relative;}
# /* sc-component-id: ReviewAndRatingsstyles__TotalReviewCountText-sc-1nxmeoo-4 */
# .iXOSqL{color:#898b91;padding-right:0.5rem;border-right:0.1rem solid #eff3f8;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}
# /* sc-component-id: ReviewAndRatingsstyles__AverageReviewWrapper-sc-1nxmeoo-5 */
# .kWDiZc{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#039556;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.iKCcrw{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#005d2f;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.pSdws{margin-right:0.5rem;padding:0.2rem 0.5rem;border-radius:0.2rem;background-color:#5fa735;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: ReviewAndRatingsstyles__AverageReviewText-sc-1nxmeoo-6 */
# .fnpNI{font-weight:bold;color:#ffffff;text-align:center;}
# /* sc-component-id: ReviewAndRatingsstyles__GoRatingBlock-sc-1nxmeoo-7 */
# .yKIfc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#039556;color:#ffffff;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}.eewuDU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#005d2f;color:#ffffff;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}.jUZxVU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#5fa735;color:#ffffff;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:13.2rem;height:10.6rem;border-radius:0.6000000000000001rem;text-align:center;margin-right:0.5rem;}
# /* sc-component-id: ReviewAndRatingsstyles__ReviewCountTextWrapper-sc-1nxmeoo-9 */
# .crLJti{font-size:1.4000000000000001rem;padding-top:0.5rem;padding-bottom:0.5rem;}
# /* sc-component-id: ReviewAndRatingsstyles__RatingsCountTextWrapper-sc-1nxmeoo-10 */
# .cGFGsN{font-size:1.4000000000000001rem;padding-bottom:1rem;}
# /* sc-component-id: ReviewAndRatingsstyles__AvgReviewTextWrapperDiv-sc-1nxmeoo-11 */
# .fRhGQt{margin-top:1rem;font-size:3rem;}
# /* sc-component-id: ReviewAndRatingsstyles__AvgReviewTextWrapper-sc-1nxmeoo-12 */
# .zxggi{font-weight:bold;}
# /* sc-component-id: ReviewAndRatingsstyles__TotalReviewTextWrapper-sc-1nxmeoo-13 */
# .jgSvbc{font-size:2.6rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;line-height:1.1;font-weight:bold;}
# /* sc-component-id: ReviewAndRatingsstyles__ReviewTypeTextWrapper-sc-1nxmeoo-15 */
# .dSRAYa{padding-right:0.5rem;font-weight:bold;line-height:1;}
# /* sc-component-id: ReviewAndRatingsstyles__ProgressBarWrapperDiv-sc-1nxmeoo-16 */
# .jQDxLE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding-top:0.30000000000000004rem;width:7rem;}
# /* sc-component-id: ReviewAndRatingsstyles__ProgressBarCountWrapper-sc-1nxmeoo-17 */
# .kPCZmY{padding-left:1.5rem;color:#898b91;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}
# /* sc-component-id: ReviewAndRatingsstyles__StarDiv-sc-1nxmeoo-18 */
# .glvbyv{cursor:pointer;margin-right:0.5rem;fill:red;}
# /* sc-component-id: ReviewAndRatingsstyles__TipPositioning-sc-1nxmeoo-20 */
# .kwDkJw{position:absolute;margin-left:-1rem;width:2.4rem;height:1.2rem;overflow:hidden;right:60%;top:-1.2rem;} .kwDkJw::after{content:'';position:absolute;width:1.3rem;height:1.2rem;left:50%;background:white;z-index:9;} .kwDkJw::after{-webkit-transform:translate(-50%,50%) rotate(45deg);-ms-transform:translate(-50%,50%) rotate(45deg);transform:translate(-50%,50%) rotate(45deg);box-shadow:0 0.1rem 0.4rem rgba(0,0,0,0.25);}
# /* sc-component-id: ReviewAndRatingsstyles__BreakupWrapperDiv-sc-1nxmeoo-21 */
# .gPTIVA{width:70%;padding-left:0.30000000000000004rem;}
# /* sc-component-id: ReviewAndRatingsstyles__OverriddenProgressBar-sc-1nxmeoo-22 */
# .eCHVqb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:7rem;height:0.8rem;background-color:#e9eff5;border-radius:0.6000000000000001rem;position:absolute;}
# /* sc-component-id: ReviewAndRatingsstyles__BreakupWrapperContainer-sc-1nxmeoo-23 */
# .kfJfGR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:0.5rem;}
# /* sc-component-id: ReviewAndRatingsstyles__ProgressLine-sc-1nxmeoo-24 */
# ...
# Hotels in Seoul |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-prague-ct/">
# Hotels in Prague |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-guangzhou-ct/">
# Hotels in Guangzhou |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-special-region-of-yogyakarta-ct/">
# Hotels in Special Region of Yogyakarta |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-hong-kong-ct/">
# Hotels in Hong Kong |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-istanbul-ct/">
# Hotels in Istanbul |
# </a><a href="//www.goibibo.com/hotels/intl-hotels-in-kathmandu-ct/">
# Hotels in Kathmandu |
# </a>
# </p><p class="fl width100">
# <span class="greyLter ico12 fb fl padR5">Top Hotels By Category</span>
# <a href="//www.goibibo.com/hotels/5-star-hotels-in-lonavala-cg/">
# 5 Star Hotels in Lonavala |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-hyderabad-cg/">
# 5 Star Hotels in Hyderabad |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-bengaluru-cg/">
# 5 Star Hotels in Bengaluru |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-dehradun-cg/">
# 5 Star Hotels in Dehradun |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-wayanad-cg/">
# 5 Star Hotels in Wayanad |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-goa-cg/">
# 5 Star Hotels in Goa |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-jaipur-cg/">
# 5 Star Hotels in Jaipur |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-ahmedabad-cg/">
# 5 Star Hotels in Ahmedabad |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-udaipur-cg/">
# 5 Star Hotels in Udaipur |
# </a><a href="//www.goibibo.com/hotels/5-star-hotels-in-kochi-cg/">
# 5 Star Hotels in Kochi |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-gangtok-cg/">
# Budget Hotels in Gangtok |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-udaipur-cg/">
# Budget Hotels in Udaipur |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-visakhapatnam-cg/">
# Budget Hotels in Visakhapatnam |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-chennai-cg/">
# Budget Hotels in Chennai |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-goa-cg/">
# Budget Hotels in Goa |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-srinagar-cg/">
# Budget Hotels in Srinagar |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-kolkata-cg/">
# Budget Hotels in Kolkata |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-delhi-cg/">
# Budget Hotels in Delhi |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-mumbai-cg/">
# Budget Hotels in Mumbai |
# </a><a href="//www.goibibo.com/hotels/budget-hotels-in-ahmedabad-cg/">
# Budget Hotels in Ahmedabad |
# </a>
# </p><p class="fl width100">
# <span class="greyLter ico12 fb fl padR5">Top Hotels By Type</span>
# <a href="https://www.goibibo.com/hotels/resorts-in-lonavala-pt/">
# Resorts in Lonavala |
# </a><a href="https://www.goibibo.com/hotels/resorts-in-pondicherry-pt/">
# Resorts in Pondicherry |
# </a><a href="https://www.goibibo.com/hotels/cottages-in-manali-pt/">
# Cottages in Manali |
# </a><a href="https://www.goibibo.com/hotels/resorts-in-corbett-pt/">
# Resorts in Jim Corbett |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-katra-ct/">
# Hotels in Katra |
# </a><a href="https://www.goibibo.com/hotels/houseboats-in-alleppey-pt/">
# Houseboat in Alleppey |
# </a><a href="https://www.goibibo.com/hotels/villas-in-goa-pt/">
# Villas in Goa |
# </a><a href="https://www.goibibo.com/hotels/houseboats-in-srinagar-pt/">
# Houseboat in Srinagar |
# </a><a href="https://www.goibibo.com/hotels/resorts-in-bangalore-pt/">
# Resorts in Bangalore |
# </a><a href="https://www.goibibo.com/hotels/resorts-in-goa-pt/">
# Resorts in Goa |
# </a><a href="//www.goibibo.com/hotels/resorts-in-kovalam-pt/">
# Resorts in Kovalam |
# </a><a href="//www.goibibo.com/hotels/resorts-in-corbett-pt/">
# Resorts in Corbett |
# </a><a href="//www.goibibo.com/hotels/resorts-in-ooty-pt/">
# Resorts in Ooty |
# </a><a href="//www.goibibo.com/hotels/resorts-in-goa-pt/">
# Resorts in Goa |
# </a><a href="//www.goibibo.com/hotels/resorts-in-manali-pt/">
# Resorts in Manali |
# </a><a href="//www.goibibo.com/hotels/service-apartments-in-coimbatore-pt/">
# Service Apartments in Coimbatore |
# </a><a href="//www.goibibo.com/hotels/service-apartments-in-goa-pt/">
# Service Apartments in Goa |
# </a><a href="//www.goibibo.com/hotels/service-apartments-in-noida-pt/">
# Service Apartments in Noida |
# </a><a href="//www.goibibo.com/hotels/service-apartments-in-navi-mumbai-pt/">
# Service Apartments in Navi Mumbai |
# </a><a href="//www.goibibo.com/hotels/service-apartments-in-jaipur-pt/">
# Service Apartments in Jaipur |
# </a>
# </p><p class="fl width100">
# <span class="greyLter ico12 fb fl padR5">Other Links</span>
# <a href="https://www.goibibo.com/hotels/hotels-in-mumbai/near-chhatrapati-shivaji-international-airport-lh/">
# Hotels near Mumbai Airport |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-amritsar/golden-temple-area-ah/">
# Hotels Near Golden Temple |
# </a><a href="https://www.goibibo.com/destinations/delhi/weekend-getaways-from-delhi/">
# Weekend getaways from Delhi |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-bangalore/near-kempegowda-international-airport-lh/">
# Hotels near Bangalore Airport |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-manali/mall-road-ah/">
# Hotels in Mall Road Manali |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-kolkata/near-dumdum-airport-lh/">
# Hotels near Kolkata Airport |
# </a><a href="https://www.goibibo.com/destinations/bangalore/weekend-getaways-from-bangalore/">
# Weekend getaways from Bangalore |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-delhi/near-new-delhi-railway-station-lh/">
# Hotels near New Delhi Railway Station |
# </a><a href="https://www.goibibo.com/hotels/the-leela-goa-hotel-in-goa-4288728801928140430/">
# The Leela Goa |
# </a><a href="https://www.goibibo.com/hotels/grand-hyatt-goa-hotel-in-goa-7052346760803278547/">
# Grand Hyatt Goa |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-delhi/near-delhi-airport-lh/">
# Hotels near Delhi Airport |
# </a><a href="https://www.goibibo.com/destinations/mumbai/weekend-getaways-from-mumbai/">
# Weekend getaways from Mumbai |
# </a><a href="https://www.goibibo.com/hotels/jw-marriott-mumbai-juhu-hotel-in-mumbai-621435388237994578/">
# JW Marriott Mumbai |
# </a><a href="https://www.goibibo.com/hotels/hotels-in-nainital/mall-road-area-ah/">
# Hotels in Mall Road Nainital |
# </a><a href="https://www.goibibo.com/hotels/chain/oyo-rooms-hotels-oyorms/">
# OYO Rooms Hotels |
# </a><a href="https://www.goibibo.com/hotels/chain/sarovar-group-of-hotels-sarovargrp/">
# Sarovar Group of Hotels |
# </a><a href="https://www.goibibo.com/hotels/chain/carlson-rezidor-hotels-carlsonrzd/">
# Carlson Rezidor Hotels |
# </a><a href="https://www.goibibo.com/hotels/chain/fortune-hotels-fortunehtl/">
# Fortune Hotels |
# </a><a href="https://www.goibibo.com/hotels/chain/club-mahindra-group-hotels-clubmhndrg/">
# Club Mahindra Group Hotels |
# </a><a href="https://www.goibibo.com/hotels/chain/taj-hotels-resorts-palaces-rtajhtlsrs/">
# Taj Hotels Resorts &amp; Palaces |
# </a>
# </p></div></div><div class="col-md-12 col-sm-12 col-xs-12 footerAppLinks"><div class="col-md-2 col-sm-3"><p class="ico14 fb">Follow Us</p><div class="padT10"><a class="fl padR10" href="http://www.facebook.com/goibibo" target="_blank" title="facebook"><i class="ico24 lh1-2 greyLt icon-facebook"></i></a><a class="fl padR10" href="http://twitter.com/goibibo" target="_blank" title="Twitter"><i class="ico26 lh1-2 greyLt icon-twitter"></i></a><a class="fl padR10" href="http://www.youtube.com/user/goibibo" target="_blank" title="youtube"><i class="ico28 greyLt icon-youtube"></i></a><a class="fl" href="https://plus.google.com/+goibibo/" target="_blank" title="Google Plus"><span class="hd_vs fr_gplus margin0"> </span></a></div></div><div class="col-md-5 col-sm-6"><p class="ico14 fb">Book Tickets faster. Download our mobile Apps</p><div class="padT10"><a class="fthm-mobApp fthm-goog fl marginR5" href="http://app.appsflyer.com/com.goibibo?pid=mobile_site&amp;c=m_header" target="_blank"></a><a class="fthm-mobApp fthm-app fl marginR5" href="https://itunes.apple.com/in/app/goibibo-flight-bus-hotel-booking/id631927169?mt=8" target="_blank"></a><a class="fthm-mobApp fthm-windows fl" href="http://www.windowsphone.com/en-in/store/app/goibibo/6f16a6ec-3b7e-4782-9f74-57f75a4cc1a3" target="_blank"></a></div></div><div class="col-md-5 col-sm-3 marginT5 pad0"><span class="commonSprite fl verifySign marginR10"> </span><span class="commonSprite fl americanExp marginT5 marginR10 ipaddn"> </span><span class="commonSprite fl masterCard marginT5 marginR10 ipaddn"> </span><span class="commonSprite fl visaCard marginT5 marginR10 ipaddn"> </span><span class="commonSprite payu marginT5 marginR10"> </span><span class="commonSprite rupay marginT2 marginR10 ipaddn"> </span><span class="commonSprite iata marginR10"> </span></div></div><div class="col-md-12 col-sm-12 col-xs-12 footerCopyrights"><div class="col-md-8"><a class="commonSprite ibGrp" href="http://www.ibibo.com/" target="_blank"></a><span class="commonSprite backslash" href="#"></span><a class="commonSprite goib" href="http://www.goibibo.com/" target="_blank"></a><a class="commonSprite redBus" href="http://www.redbus.in/" rel="nofollow" target="_blank"></a></div><div class="fr padT10">© 2020 ibibogroup All rights reserved</div></div></div></div></div>
# <div id="modal-root"></div>
# <script type="text/javascript">
#             function pageSeen(stage) {
#                 if (!starttime) {
#                     // starttime should be defined on top of the page in the head
#                     return;
#                 }
#                 try {
#                     var endPoint = "//dexter.goibibo.com/common/ping/";
#                     var loc = window.location.pathname;
#                     var timeStamp = (new Date() - starttime) / 1000;
#                     var url = endPoint + "?jsLoaded=" + stage + "&pageseen=" + loc + "&timestamp=" + timeStamp + '&application=avatar' + "&flavour=dweb" + "&docReferer=" + document.referrer + "&timelog=" + new Date().toISOString();
#                     var xhr = new XMLHttpRequest();
#                     xhr.open("GET", url, true);
#                     xhr.withCredentials = true;
#                     xhr.send();
#                 } catch(err) {
#                     console.log(err);
#                 }
#             }
#             // track raw page views
#             pageSeen('FMP');
#         </script>
# <script charset="UTF-8">
#           window.cachedAt="7/31/2020, 12:33:38 AM";
#           window.__initial_state__={"user":{"isLoading":false,"userInfo":{"profile_type":"personal","userid":null},"gocashInfo":null,"isLoggedIn":false,"showLoginPopup":false},"srp":{"hasData":true,"isLoading":false,"displayOverlay":false,"partner":"hotels","srpConfig":{"s":"popularity","cur":"INR","im":true,"filter":{},"seoViewMore":true},"srpData":{"city_meta_info":{"pxgrn":0,"altpx":"","pot":[{"oi":"1","ot":"30% or more"},{"oi":"2","ot":"50% or more"},{"oi":"3","ot":"80% or more"}],"sb_msg":"","sb":0,"banner_type":"","scthr":15,"is_ipl":0,"collections":[{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002FGoa-Villa-1573122051.jpg","slug":"alt_acco_longstay","st":"","t":"Upto 30% OFF* on Long Stays!","desc":"Unlock amazing discounts* for 4D\u002F3N bookings & more"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fdod-thumb-1564570672.jpg","slug":"dh_dealsoftheday","st":"","t":"Daily Steal Deals","desc":"Best hotel deals running today!"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fflash-deal-thumb-1560489630.jpg","slug":"dh_hcpdeals","st":"","t":"Flash Deals","desc":"Short-term mega discounts on your favourite properties. Find your best deal NOW!"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Ffamily-kids-thumb-1557219561.jpg","slug":"dh_familywithkids","st":"","t":"Family trip with kids","desc":"Child Friendly Amenities | Child Below 5 yrs of age stays free | Large Rooms"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002F4-5-Star-Hotel-thumb-1555051096.jpg","slug":"5_at_3","st":"","t":"5 Star Hotels at 3 Star Prices","desc":"Book your favorite 5 star hotels at 3 star prices!"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002F4-5-Star-Hotel-thumb-1555051096.jpg","slug":"4_at_3","st":"","t":"4 Star hotels at 3 Star Prices","desc":"Book your favorite 4 star hotels at 3 star prices!"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002F4-5-Star-Hotel-thumb-1555051096.jpg","slug":"dh_4_and_5","st":"","t":"Premium Stays ","desc":"Make better memories this holiday!\n"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002F3-Star-Hotel-thumb-1555051074.jpg","slug":"dh_3","st":"","t":"The Affordable Luxury","desc":"Handpicked 3-star properties\n"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002FHotels-near-temple-thumb-1553239514.jpg","slug":"auto_1449073512565742573_shimla_9179355360202682496","st":"","t":"Near Jakhoo Temple","desc":""},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002FHotels-near-temple-thumb-1553239514.jpg","slug":"auto_1449073512565742573_shimla_6297461437893329290","st":"","t":"Near Jwala Devi Temple Himachal","desc":""},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002FTop-rated-budget-hotels-thumb-1553239682.jpg","slug":"top_user_rated_budget_htl","st":"","t":"Top Rated Budget Hotels","desc":"Top User Rated Budget hotels"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fgostays-cf-thumb-1569844938.jpg","slug":"dh_cfgostays","st":"","t":"Couple Friendly goStays","desc":"✓ Good Ratings ✓ Unmarried Couples ✓ Local IDs"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fcleanstays-1584460400.png","slug":"dh_vande_bharat","st":"","t":"Hotel Deals So Fabulous","desc":"That it will make you look twice"}],"segments":[{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fweekend_deal_thumbnail_main-1593511881.png","slug":"dh_staycation","st":"","t":"Super Deals","desc":""},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fthumb-gosafe-1588441329.png","slug":"dh_gosafe","st":"Introducing","t":"goSafe Properties","desc":"Safe and hygienic places to stay for your upcoming trips"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fcouple-thumb-1553234869.jpg","slug":"dh_cf","st":"Preferred by","t":"Couples","desc":"Hotels Preferred by Couples"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fgostays-thumb-1569576453.jpg","slug":"dh_gostays","st":"","t":"goStays","desc":"goStays - Goibibo Certified Hotels with assured Clean Rooms, Free Wifi, AC, TV and a 100% Money Back Guarantee"},{"img":"https:\u002F\u002Fgos3.ibcdn.com\u002Fbusiness-thumb-1538718880.jpg","slug":"dh_business_friendl ...
#         </script>
# <script src="https://goibibo.ibcdn.com/s3/avatar/static/js/vendors~avatar.459b0f36.chunk.js"></script><script src="https://goibibo.ibcdn.com/s3/avatar/static/js/avatar.459b0f36.js"></script>
# <script charset="UTF-8" defer="" src="https://goibibo.ibcdn.com/s3/avatar/custom-scripts/lc-lpc.js?v=1" type="text/javascript"></script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TJ88JPS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TJ88JPS');</script>
# <script charset="UTF-8" defer="" src="/flt_hotelsnstatic/lib/hotjar.js" type="text/javascript"></script>
# <script crossorigin="anonymous" defer="" onload="window.Raven &amp;&amp; Raven.config('https://41d8fc9f844e4973af1d142b57294396@bugs.goibibo.com/161').install();" src="https://goibibo.ibcdn.com/js/v2/raven.min.js"></script>
# <script type="text/javascript">var _cf = _cf || []; _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/static/f41d3553dc8ti239f23a5b1713b3cc1c6']); </script><script src="/static/f41d3553dc8ti239f23a5b1713b3cc1c6" type="text/javascript"></script></body>
# </html>

# %% [markdown]
# The next step is to parse this data into an HTML Parser and for that, we will use the **BeautifulSoup** library. Now, if you have noticed our target web page, the details of a particular hotel are on a different card like most of the web pages.
# So the next step would be to filter this card data from the complete source code. Next, we will select the card and click on the ‘Inspect Element’ option to get the source code of that particular card. You will get something like this:
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/source-cord-card-mapping.png)
#
# The class name of all the cards would be the same and we can get a list of those cards by just passing the tag name and attributes like the **< /class>**
# tag with its name like I’ve shown below:

# %%
# find all the sections with specifiedd class name

cards_data = data.find_all('div', attrs={'class', 'HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ'})

# %%
# total number of cards
print('Total Number of Cards Found : ', len(cards_data))
# Out:
# Total Number of Cards Found :  10

# %%
# source code of hotel cards
for card in cards_data:
  print(card)
# Out:
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="4" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="3" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="5" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="4" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="3" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><div class="Layouts__Column-sc-1yzlivq-1 HotelCardImageGallerystyles__GoStaysIconWrapperForImageListDiv-r3dzqu-7 inZapl"><span class="HotelCardImageGallerystyles__GoStaysIconWrapperForImageListSpan-r3dzqu-8 Igtul"><svg class="GoStaysIcon-sc-6ymekq-0 ksgKxx" fill="#ff6d38" height="3.2rem" viewbox="0 0 32 32" width="3.2rem"><path d="M32 16c0 8.837-7.163 16-16 16S0 24.837 0 16 7.163 0 16 0s16 7.163 16 16zm-16.657-2.645V6.041h-2.537v.96h-.032c-.498-.774-1.247-1.161-2.248-1.161-1.119 0-2.02.411-2.705 1.234s-1.027 1.933-1.027 3.331c0 1.247.308 2.242.923 2.984s1.448 1.113 2.497 1.113c1.129 0 1.983-.462 2.561-1.387h.032v.653c0 .779-.236 1.396-.706 1.851s-1.135.681-1.991.681c-.862 0-1.715-.247-2.561-.742v2.145c.647.317 1.525.476 2.633.476 1.675 0 2.954-.421 3.837-1.262s1.325-2.028 1.325-3.561zm5.17 1.145c1.392 0 2.487-.398 3.287-1.194s1.2-1.879 1.2-3.25c0-1.269-.388-2.289-1.164-3.061s-1.846-1.157-3.211-1.157c-1.386 0-2.486.386-3.299 1.157s-1.22 1.84-1.22 3.206c0 1.322.392 2.37 1.176 3.141s1.861 1.157 3.231 1.157zm4.532 9.95l-18.348.005v-.242h-.241v1.005h.236v-.291h16.01v.69h.278v-.399h.387v.715h.387v-.739h.483v.932h.483v-1.223h.326v-.453zm-18.208-.902c.166.086.363.149.59.193.226.043.466.064.717.064.245 0 .478-.023.698-.07s.413-.124.579-.232c.166-.107.298-.248.395-.422s.145-.387.145-.643c0-.186-.028-.348-.083-.487s-.136-.264-.24-.372c-.104-.108-.229-.206-.375-.292s-.31-.167-.493-.244c-.135-.056-.255-.11-.361-.162s-.197-.105-.272-.16c-.074-.055-.132-.112-.172-.173a.369.369 0 01-.007-.396.45.45 0 01.154-.145c.066-.04.147-.072.243-.094s.202-.034.32-.034a2.167 2.167 0 01.556.079 1.82 1.82 0 01.53.241v-.956c-.155-.06-.325-.104-.51-.133s-.396-.043-.634-.043c-.243 0-.473.026-.69.078s-.408.133-.573.244c-.165.111-.296.252-.391.423s-.144.376-.144.615c0 .305.088.564.264.779s.443.397.8.546c.141.057.272.113.393.169s.226.113.314.172c.088.059.158.125.209.195a.399.399 0 01.028.424.423.423 0 01-.145.147c-.065.041-.146.073-.243.097s-.21.036-.34.036a1.954 1.954 0 01-1.261-.466v1.022zm6.899-3.564v-.84h-3.642v.84h1.3v3.741h1.035v-3.741h1.306zm4.455 3.74l-1.629-4.581h-1.223l-1.668 4.581h1.118l.323-1.019h1.629l.326 1.019h1.124zm-5.352-13.393c0 .667-.162 1.203-.486 1.609s-.748.609-1.272.609c-.53 0-.947-.2-1.252-.601s-.458-.945-.458-1.633c0-.801.161-1.422.482-1.863s.763-.661 1.325-.661c.492 0 .892.184 1.2.552s.462.813.462 1.335v.653zm7.738-2.54c1.225 0 1.838.772 1.838 2.314 0 1.629-.607 2.444-1.822 2.444-1.274 0-1.911-.793-1.911-2.379 0-.758.166-1.344.498-1.758s.797-.621 1.397-.621zm-4.073 14.122v-.001h-1.173l.499-1.552c.043-.133.069-.265.08-.399h.025c.014.16.04.298.077.412l.491 1.54zm5.516-2.77v-.001h-1.093l-.75 1.722a1.591 1.591 0 00-.099.361h-.013a6.096 6.096 0 00-.106-.374l-.738-1.709h-1.179l1.453 2.971v1.61h1.032v-1.629l1.492-2.952zm.116 4.405c.166.086.363.149.589.193a3.758 3.758 0 001.414-.006c.221-.046.4 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="3" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="3" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><div class="Layouts__Column-sc-1yzlivq-1 HotelCardImageGallerystyles__GoStaysIconWrapperForImageListDiv-r3dzqu-7 inZapl"><span class="HotelCardImageGallerystyles__GoStaysIconWrapperForImageListSpan-r3dzqu-8 Igtul"><svg class="GoStaysIcon-sc-6ymekq-0 ksgKxx" fill="#ff6d38" height="3.2rem" viewbox="0 0 32 32" width="3.2rem"><path d="M32 16c0 8.837-7.163 16-16 16S0 24.837 0 16 7.163 0 16 0s16 7.163 16 16zm-16.657-2.645V6.041h-2.537v.96h-.032c-.498-.774-1.247-1.161-2.248-1.161-1.119 0-2.02.411-2.705 1.234s-1.027 1.933-1.027 3.331c0 1.247.308 2.242.923 2.984s1.448 1.113 2.497 1.113c1.129 0 1.983-.462 2.561-1.387h.032v.653c0 .779-.236 1.396-.706 1.851s-1.135.681-1.991.681c-.862 0-1.715-.247-2.561-.742v2.145c.647.317 1.525.476 2.633.476 1.675 0 2.954-.421 3.837-1.262s1.325-2.028 1.325-3.561zm5.17 1.145c1.392 0 2.487-.398 3.287-1.194s1.2-1.879 1.2-3.25c0-1.269-.388-2.289-1.164-3.061s-1.846-1.157-3.211-1.157c-1.386 0-2.486.386-3.299 1.157s-1.22 1.84-1.22 3.206c0 1.322.392 2.37 1.176 3.141s1.861 1.157 3.231 1.157zm4.532 9.95l-18.348.005v-.242h-.241v1.005h.236v-.291h16.01v.69h.278v-.399h.387v.715h.387v-.739h.483v.932h.483v-1.223h.326v-.453zm-18.208-.902c.166.086.363.149.59.193.226.043.466.064.717.064.245 0 .478-.023.698-.07s.413-.124.579-.232c.166-.107.298-.248.395-.422s.145-.387.145-.643c0-.186-.028-.348-.083-.487s-.136-.264-.24-.372c-.104-.108-.229-.206-.375-.292s-.31-.167-.493-.244c-.135-.056-.255-.11-.361-.162s-.197-.105-.272-.16c-.074-.055-.132-.112-.172-.173a.369.369 0 01-.007-.396.45.45 0 01.154-.145c.066-.04.147-.072.243-.094s.202-.034.32-.034a2.167 2.167 0 01.556.079 1.82 1.82 0 01.53.241v-.956c-.155-.06-.325-.104-.51-.133s-.396-.043-.634-.043c-.243 0-.473.026-.69.078s-.408.133-.573.244c-.165.111-.296.252-.391.423s-.144.376-.144.615c0 .305.088.564.264.779s.443.397.8.546c.141.057.272.113.393.169s.226.113.314.172c.088.059.158.125.209.195a.399.399 0 01.028.424.423.423 0 01-.145.147c-.065.041-.146.073-.243.097s-.21.036-.34.036a1.954 1.954 0 01-1.261-.466v1.022zm6.899-3.564v-.84h-3.642v.84h1.3v3.741h1.035v-3.741h1.306zm4.455 3.74l-1.629-4.581h-1.223l-1.668 4.581h1.118l.323-1.019h1.629l.326 1.019h1.124zm-5.352-13.393c0 .667-.162 1.203-.486 1.609s-.748.609-1.272.609c-.53 0-.947-.2-1.252-.601s-.458-.945-.458-1.633c0-.801.161-1.422.482-1.863s.763-.661 1.325-.661c.492 0 .892.184 1.2.552s.462.813.462 1.335v.653zm7.738-2.54c1.225 0 1.838.772 1.838 2.314 0 1.629-.607 2.444-1.822 2.444-1.274 0-1.911-.793-1.911-2.379 0-.758.166-1.344.498-1.758s.797-.621 1.397-.621zm-4.073 14.122v-.001h-1.173l.499-1.552c.043-.133.069-.265.08-.399h.025c.014.16.04.298.077.412l.491 1.54zm5.516-2.77v-.001h-1.093l-.75 1.722a1.591 1.591 0 00-.099.361h-.013a6.096 6.096 0 00-.106-.374l-.738-1.709h-1.179l1.453 2.971v1.61h1.032v-1.629l1.492-2.952zm.116 4.405c.166.086.363.149.589.193a3.758 3.758 0 001.414-.006c.221-.046.414-.124.58-.232s.298-.248.395-.422a1.31 1.31 0 00.145-.643c0-.186-.028-.348-.083-.487s-.134-.264-.239-.372c-.105-.108-.229-.206-.375-.292s-.31-.167-.494-.244c-.134-.056-.254-.11-.361-.162s-.197-.105-.272-.16a.67.67 0 01-.172 ...
# <div class="HotelCardstyles__OuterWrapperDiv-sc-1s80tyk-0 eXWmAQ" itemscope="" itemtype="http://schema.org/Hotel"><div class="HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 fKNNeH"><span class="PersuasionHoverTextstyles__WrapperDiv-sc-1c06rw1-13 hmlsFt"><span class="PersuasionHoverTextstyles__HoverTargetWrapperDiv-sc-1c06rw1-2 dfSYRF" type=""><div class="HotelCardDealTag__WrapperDiv-sc-8faxgn-0 bcGOvP" color="#ffffff"><div class="HotelCardDealTag__TagMarkup-sc-8faxgn-2 hivUQz"></div><span class="HotelCardDealTag__TextWrapperSpan-sc-8faxgn-1 gErUjJ">Hot Deal</span></div></span></span><div class="HotelCardstyles__ImageGalleryWrapperDiv-sc-1s80tyk-1 iGkcms"><div class="FreeBreakfastTag__WrapperDiv-sc-1t1x6un-0 gMWZSi"><div class="FreeBreakfastTag__TagMarkup-sc-1t1x6un-2 ksKWcf"></div><span class="FreeBreakfastTag__TextWrapperSpan-sc-1t1x6un-1 fyWKnD">Free Breakfast</span></div><img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/><ul class="HotelCardImageGallerystyles__ImageList-r3dzqu-4 daowQn"><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><li><img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/></li><div class="HotelCardImageGallerystyles__ViewAllWrapperStyle-r3dzqu-5 hJwPoW"><span class="HotelCardImageGallerystyles__ViewAllTextStyle-r3dzqu-6 fihdE">View All</span></div></ul></div><div class="HotelCardstyles__HotelCardInfoWrapperDiv-sc-1s80tyk-6 jnRyOY"><div class="HotelCardstyles__HotelInfoWrapperDiv-sc-1s80tyk-7 dSCqXd"><div class="HotelCardstyles__HeadingInfoWrapperDiv-sc-1s80tyk-9 ynTNd"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><div class="dwebCommonstyles__CenteredSpaceWrap-sc-112ty3f-0 dgKLZs"><span content="3" itemprop="starRating"><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00-1.537 0l-1.58 3.776-4.036.348C.031 4.7-.27 5.632.29 6.124l3.067 2.698-.92 4.005c-.166.73.61 1.307 1.246.916l3.468-2.12z" fill="#FDBA00"></path></g></svg><svg class="RatingStarIcon-sc-1lv0lb2-0 ckdrFt" height="14" width="15"><g fill="none" fill-rule="evenodd"><path d="M-5-5h24v24H-5z"></path><path d="M7.15 11.622l3.469 2.13c.635.39 1.412-.187 1.245-.917l-.92-4.004 3.068-2.699c.56-.492.259-1.425-.477-1.484L9.5 4.3 7.92.515a.831.831 0 00 ...

# %% [markdown]
# We have filtered the cards data from the complete source code of the web page and each card here contains the information about a separate hotel. Select only the Hotel Name, perform the Inspect Element step, and do the same with the Room Price:
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/inspect-element-nested1.png)
#
# Now, for each card, we have to find the above Hotel Name which can be extracted from the (p) tag only. **This is because there is only one (p) tag for each card and Room Price by (li) tag along with the (class) tag and class name:**

# %%
# extract the hotel name and price per room
for card in cards_data:
  
  # get the hotel name
  hotel_name = card.find('a')

  # get the room price
  room_price = card.find('span', attrs={'itemprop': 'priceRange'})

  print(hotel_name, room_price)
# Out:
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Snow Valley Resorts" href='/hotels/snow-valley-resorts-hotel-in-shimla-1953288179585905793/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Snow Valley Resorts</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">3361</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Rocky Knob (Explore World Art in One Property)" href='/hotels/rocky-knob-explore-world-art-in-one-property-hotel-in-shimla-6025344523708922203/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Rocky Knob (Explore World Art in One Property)</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">2593</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Radisson Jass Shimla" href='/hotels/radisson-jass-shimla-hotel-in-shimla-3399253684009777930/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v15"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Radisson Jass Shimla</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">8000</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Hotel Willow Banks" href='/hotels/willow-banks-hotel-in-shimla-4098314048100585768/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Hotel Willow Banks</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">5275</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="The Oaktree House" href='/hotels/the-oaktree-house-hotel-in-shimla-6582857422120530423/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">The Oaktree House</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">2971</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Hotel Sidharath" href='/hotels/sidharath-hotel-in-shimla-2599470256323068721/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Hotel Sidharath</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">1305</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Hotel Sangeet" href='/hotels/sangeet-hotel-in-shimla-8871636629353578439/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Hotel Sangeet</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">1637</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Hotel Cosmos" href='/hotels/cosmos-hotel-in-shimla-5937000712051274523/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Hotel Cosmos</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">1707</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="New Cosmos" href='/hotels/new-cosmos-hotel-in-shimla-4637820275887385447/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">New Cosmos</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">1592</span>
# <a class="HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 hiSwbR" content="Hotel Aachman Regency" href='/hotels/aachman-regency-hotel-in-shimla-6045723022250842323/?hquery={"ci":"20200806","co":"20200807","r":"1-2-0","ibp":"v3"}&amp;hmd=...&amp;cc=IN' itemprop="name" target="_blank">Hotel Aachman Regency</a> <span class="HotelCardstyles__CurrentPrice-sc-1s80tyk-25 dfIkHO" itemprop="priceRange">1547</span>

# %% [markdown]
# The final step is to store the extracted data in the CSV file. Here, for each card, we will extract the Hotel Name and Price and store it in a Python dictionary. We will then finally append it to a list.
# Next, let’s go ahead and transform this list to a Pandas data frame as it allows us to convert the data frame into CSV or JSON files:

# %%
# create a list to store the data
scraped_data = []

for card in cards_data:
  
  # initialize the dictionary
  card_details = {}

  # get the hotel name
  hotel_name = card.find('a')

  # get the room price
  room_price = card.find('span', attrs={'itemprop': 'priceRange'})

  # get the hotel rating
  hotel_rating = card.find('span', attrs={'itemprop':'ratingValue'})

  # get the hotel star rating
  #hotel_add = card.find('span', attrs={'class':'PersuasionHoverTextstyles__TextWrapperSpan-sc-1c06rw1-14 dlEtqh'}) 

  # add data to the dictionary
  card_details['Hotel_Name'] = hotel_name.text
  card_details['Room_Price'] = room_price.text
  card_details['Hotel_Ratings']= hotel_rating.text
  #card_details['Hotel_Location']= hotel_add.text 

  # append the scraped data to the list
  scraped_data.append(card_details)

# %%
# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)
dataFrame.head()
# Out:
#                                        Hotel_Name Room_Price Hotel_Ratings
# 0                             Snow Valley Resorts       3361       4.4 / 5
# 1  Rocky Knob (Explore World Art in One Property)       2593       4.6 / 5
# 2                            Radisson Jass Shimla       8000       4.4 / 5
# 3                              Hotel Willow Banks       5275       4.1 / 5
# 4                               The Oaktree House       2971       4.8 / 5

# %%
# save the scraped data as CSV file
dataFrame.to_csv('Hotel_Data.csv',index=False)

# %% [markdown]
# Congrats! We have successfully created a basic web scraper. I want you to try out these steps and try to get more data like ratings and address of the hotel. Now let’s see how to perform some common tasks like scraping URLs, Email IDs, Images, and Scrape Data on Page Loads.

# %% [markdown]
# # **Single Webpage Scraping**

# %% [markdown]
# Two of the most common features we try to scrape are website URLs and email IDs. I'm sure you've worked on projects or challenges where extracting email IDs in bulk was required (see marketing teams!). So let's see how to scrape these aspects in Python.
#
# #### **Using the Console of the Web Browser**
# *  Let's say we want to keep track of our Instagram followers and want to know the username of the person who unfollowed our account. First, log in to your Instagram account and click on followers to check the list:
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/instagram_blurred.png)
#
# *  Scroll down all the way so that we have all the usernames loaded in the background in our browser's memory
# *  Right-click on the browser's window and click 'Inspect Element'
# *  In the Console Window, type this command:
#
# ## **`urls = $$('a'); for (url in urls) console.log ( urls[url].href);`**
#
# ![alt text](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/console.png)
# *  With just one line of code, we can find out all the URLs present on that particular page:
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2019/09/usernames-blurred.png)
# *  Next, save this list at two different time stamps and a simple Python program will let you know the difference between the two. We would be able to know the username of who unfollowed our account!
# *  There can be multiple ways we can use this hack to simplify our tasks. The main idea is that with a single line of code we can get all the URLs in one go
#
# #### **Using the Chrome Extension Email Extractor**
# *  [Email Extractor](https://chrome.google.com/webstore/detail/email-extractor/jdianbbpnakhcmfkcckaboohfgnngfcc?hl=en) is a Chrome plugin that captures the Email IDs present on the page that we are currently browsing.
# *  It even allows us to download the list of Email IDs in CSV or Text file:
# ![](https://s3.amazonaws.com/thinkific/file_uploads/118220/images/497/1cd/31d/1586174856067.jpg)

# %% [markdown]
# # **Multiple Webpage Scraping (BeautifulSoup and Regex)**

# %% [markdown]
# The above solutions are efficient only when we want to scrape data from just one page. But what if we want the same steps to be done on multiple webpages?
# There are many websites that can do that for us at some price. But here’s the good news – we can also write our own web scraper using Python! You can use the code below:

# %%
# Web Scraping - URLs and Email IDs
import urllib.request
from bs4 import BeautifulSoup

# %%
# URL to Scrap
wiki = "https://dlca.logcluster.org/display/public/DLCA/4.1+Nepal+Government+Contact+List"

# %%
#Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(wiki)

# %%
#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page,features='html.parser')
print('\n\nPage Scrapped !!!\n\n')
print('\n\nTITLE OF THE PAGE\n\n')
# Out:
# Page Scrapped !!!
#
#
#
#
# TITLE OF THE PAGE

# %%
print(soup.title.string)
print('\n\nALL THE URLs IN THE WEB PAGE\n\n')
# Out:
# 4.1 Nepal Government Contact List - Logistics Capacity Assessment - Digital Logistics Capacity Assessments
#
#
# ALL THE URLs IN THE WEB PAGE

# %%
all_links = soup.find_all('a')
print('Total number of URLs present = ',len(all_links))
# Out:
# Total number of URLs present =  108

# %%
print('\n\nLast 5 URLs in the page are : \n')

if len(all_links) > 5:

  last_5 = all_links[len(all_links)-5:]

  for url in last_5:
    print(url.get('href'))
# Out:
# Last 5 URLs in the page are :
#
# http://www.atlassian.com/c/conf/11460
# http://www.atlassian.com/software/confluence
# https://support.atlassian.com/help/confluence
# http://www.atlassian.com/about/connected.jsp?s_kwcid=Confluence-stayintouch
# http://www.atlassian.com/

# %%
emails=[]
for url in all_links:
  if (str(url.get('href')).find('@') > 0):
    emails.append(url.get('href'))

print('\n\nTotal Number of Email IDs Present: ', len(emails))
# Out:
# Total Number of Email IDs Present:  27

# %%
print('\n\nSome of the emails are: \n\n')
for email in emails[:5]:
  print(email)
# Out:
# Some of the emails are:
#
#
# mailto:info@nepal.gov.np
# mailto:info@moad.gov.np
# mailto:info@mod.gov.np
# mailto:info@mohp.gov.np
# mailto:gunaso@moha.gov.np

# %% [markdown]
# # **Scrape Images in Python**

# %% [markdown]
# In this section, we will scrape all the images from the same *Goibibo* webpage. The first step would be the same to navigate to the target website and download the source code. Next, we will find all the images using the (img) tag.

# %%
# importing required libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %%
# target URL
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

headers = {'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"}

response = requests.request("GET", url, headers=headers)

data = BeautifulSoup(response.text, 'html.parser')

# %%
# find all with the image tag
images = data.find_all('img', src=True)
print('Number of Images: ', len(images))
# Out:
# Number of Images:  66

# %%
for img in images:
  print(img)
# Out:
# <img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="753931433" src="https://goibibo.ibcdn.com/styleguide/images/goLogo.png"/>
# <img alt="irctc train logo" class="marginT5 marginB5" height="25px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="137809912" src="https://goibibo.ibcdn.com/styleguide/images/train_logo.png" width="24px"/>
# <img class="fl" height="23px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1432842091" src="https://goibibo.ibcdn.com/styleguide/images/goCash-header.png" width="23px"/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 cYXNlx" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 cYXNlx" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 cYXNlx" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 cYXNlx" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 beqcaa" data-testid="" itemprop="image" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 gVnLtq" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>
# <img class="GoSafeDetailedPersuasionstyles__GosafeImg-sc-7q397w-3 cYXNlx" data-testid="" itemprop="" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1859759222" src="..."/>

# %% [markdown]
# From all the image tags, select only the **scr** part. Also, notice that the hotel images are available in **jpg** format. So we will select only those:

# %%
# select src tag
image_src = [x['src'] for x in images]

# select only jp format images
#image_src = [x for x in image_src if x.endswith('.png')]

for img in image_src:
  print(img)
# Out:
# https://goibibo.ibcdn.com/styleguide/images/goLogo.png
# https://goibibo.ibcdn.com/styleguide/images/train_logo.png
# https://goibibo.ibcdn.com/styleguide/images/goCash-header.png
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...:image/gif;base64,R0lGODlhAQABAIAAAAAAAP///yH5BAEAAAAALAAAAAABAAEAAAIBRAA7
# ...

# %%
len(image_src)
# Out:
# 3

# %% [markdown]
# Now that we have a list of image URLs, all we have to do is request the image content and write it in a file. Make sure that you open the file **'wb (write binary)'** form:

# %%
image_count = 1
for img in image_src:

  with open('image_'+str(image_count)+'.png', 'wb') as f:
    res = requests.get(img)
    f.write(res.content)
  
  image_count = image_count+1
